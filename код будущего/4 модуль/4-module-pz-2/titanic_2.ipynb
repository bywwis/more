# %% [markdown]
# <a href="https://colab.research.google.com/github/bywwis/4-module/blob/pz1-part2/titanic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Проверочное задание. Операции с данными. Titanic

# %%
# Импортируй библиотеку pandas
import pandas as pd

# ... и numpy:
import numpy as np

# %%
# Импортируй библиотеки для построения диаграмм
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Примонтируй Google Drive.
# В процессе выполнения кода этой ячейки перейди по длинной ссылке, скопируй код, вставь его
# в поле ввода и нажми <Enter>. Твой личный Google-диск "примонтируется", его папки
# станут видны в разделе файловой структуры слева.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Размести на Google Drive файл titanic_train.csv из материалов к заданию и загрузи его в dataframe

titanic = pd.read_csv('/content/drive/MyDrive/mydata/titanic_train.csv')

# %%
# Выведи 3 верхних строки датасета
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Выведи описательные статистики и сделай предположение о количестве пропусков в данных
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Проверь, сколько nan в столбце 'Age'
titanic.isnull().sum().sum()
# Out:
# 866

# %%
# Заполни пропуски медианным значением
titanic.fillna(titanic['Age'].median(), inplace=True)
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Построй гистограмму возраста пассажиров
titanic.Age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Вывод корреляций в датасете
corr = titanic.Age.corr(titanic['Age'])
print(corr)
# Out:
# 1.0

# %%
# Визуализируй корреляционную матрицу. Используй sns.heatmap()

# %% [markdown]
# ###
